# %%
import os
import csv
import json
from io import StringIO
from zipfile import ZipFile
from os.path import join
from collections import defaultdict, Counter
from glob import glob
from heapq import nsmallest, nlargest

# %%
REPORTS = '../data/facebook/reports'
NULL_DISCLAIMER = 'These ads ran without a disclaimer'

COUNTRIES = [
    'AT',
    'BE',
    'BG',
    'CY',
    'CZ',
    'DE',
    'DK',
    'EE',
    'ES',
    'FI',
    'FR',
    'GB',
    'GR',
    'HR',
    'HU',
    'IE',
    'IT',
    'LT',
    'LU',
    'LV',
    'MT',
    'NL',
    'PL',
    'PT',
    'RO',
    'SE',
    'SI',
    'SK',
    'US'
]

CURRENCY_RATES = {
    'EUR': 1,
    'USD': 0.88,
    'CZK': 0.039,
    'DKK': 0.134,
    'GBP': 1.12,
    'HUF': 0.0031,
    'PLN': 0.235,
    'RON': 0.21,
    'SEK': 0.095
}

# %%
# Finding unique advertisers and the country they operate in
ADVERTISERS = {}

for country in COUNTRIES:
    folder = join(REPORTS, country)
    
    last_date = sorted(d for d, _, _, in os.walk(folder))[-1].split('/')[-1]
    zip_path = glob(join(REPORTS, country, last_date, '*_lifelong.zip'))[0]

    with ZipFile(zip_path) as zipfile:
        csv_entry = next(e for e in zipfile.infolist() if e.filename.endswith('.csv'))
        
        with zipfile.open(csv_entry.filename) as csv_f:
            csv_io = StringIO(csv_f.read().decode('utf-8-sig'))
            reader = csv.DictReader(csv_io)
            currency_field = next(f for f in reader.fieldnames if f.startswith('Amount Spent'))
            currency = currency_field.split('(')[-1].split(')')[0]
            
            for line in reader:
                disclaimer = line['Disclaimer']
                page_name = line['Page Name']
                page_id = line.get('Page ID')
                spent = int(line[currency_field].replace('≤', ''))
                ads = int(line['Number of Ads in Library'].replace('≤', ''))
                
                has_disclaimer = disclaimer != NULL_DISCLAIMER
                advertiser = disclaimer if has_disclaimer else page_name
                
                record = ADVERTISERS.get(advertiser)

                if record is None:
                    record = {
                        'disclaimer': disclaimer,
                        'page_name': page_name,
                        'page_id': page_id,
                        'advertiser': advertiser,
                        'advertiser_kind': 'disclaimer' if has_disclaimer else 'page',
                        'countries': set(),
                        'spent': Counter(),
                        'spent_euro': Counter(),
                        'ads': Counter()
                    }
                    ADVERTISERS[advertiser] = record
                    
                record['countries'].add(country)
                record['spent'][country] += spent
                record['ads'][country] += ads
                record['spent_euro'][country] += spent * CURRENCY_RATES[currency]

# %%
class CustomJSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, set):
            return list(obj)
        
        return json.JSONEncoder.default(self, obj)

with open('../international_facebook_advertising.json', 'w') as jsonf:
    json.dump(ADVERTISERS, jsonf, ensure_ascii=False, cls=CustomJSONEncoder)

# %%
def sum_spent(a):
    return sum(a['spent_euro'].values())

def sum_ads(a):
    return sum(a['ads'].values())

top = nlargest(100, (a for a in ADVERTISERS.values() if len(a['countries']) > 1), key=sum_spent)

for a in top:
    print(a['advertiser'], sum_spent(a), len(a['countries']))
    a['sum_spent'] = sum_spent(a)
    a['sum_ads'] = sum_ads(a)
    a['nb_countries'] = len(a['countries'])
#    for c in a['countries']:
#        print('  %s' % c)

with open('../top-advertisers.json', 'w') as jsonf:
    json.dump(top, jsonf, ensure_ascii=False, cls=CustomJSONEncoder, indent=2)
# Out:
# Facebook 10964686.29 11
# Care2 4573409.52 2
# International Rescue Committee 3448097.32 7
# European Parliament 3169695.9619 28
# Ben & Jerry's 1032531.2799999999 4
# USA for UNHCR 975856.48 8
# Friends of the Earth 767723.36 2
# TOMS 520587.12 3
# Wholesome Culture 411828.41 27
# Patagonia 395254.32 2
# the Liberal Democrats 347292.93 18
# The Labour Party 307466.07999999996 2
# Kialo 269836.01 29
# SPÖ 184029 2
# European Greens 164995.26 27
# Seventh Generation 158535.075 2
# Giving Brush LLC 155713.92 2
# Uniunea Salvați România - USR 127391.70599999998 11
# Centerpartiet 126970.665 2
# Avaaz 120383.48 6
# Audible 120183.6 2
# European Commission 113961.78 27
# The Years Project 88072.03 21
# MasterClass 76189.05 28
# Kristdemokraterna 72596.94000000002 2
# Clone Evolution 55043.36 2
# Momentum Mozgalom 53657.31740000001 2
# Unilever 52412.0 3
# Parti Socialiste (PS) 52118 2
# Grüner Fisher Investments 51014 2
# Campact e.V. 49700 2
# Sperry 49355.6 4
# Giving Brush 41406.31 21
# Doha Debates 40992.4 3
# EPP - European People's Party 40874.37 27
# Progresívne Slovensko 37329.11 22
# The Palestine Institute for Public Diplomacy 29881.100000000002 17
# Världsnaturfonden WWF 28365.32 2
# Big News Buzz 27925.77 27
# Coca-Cola 26745.6 2
# China Xinhua News 26508.48 2
# Kokoomus 26294.0 2
# Prizeo 22530.170000000002 28
# BP 22109.68 2
# IKEA 20535.824 3
# Lizette Risgaard 19327.452 2
# Raimond Kaljulaid 17421.210000000003 13
# Fred Keller for Congress 17387.16 5
# Basmah 17137.850000000002 27
# Maggie De Block 15816.0 2
# The Week UK 15813.920000000002 2
# Zox 15568.489999999998 28
# Global Citizen 15541.89 26
# EU Environment 15176.02 16
# RBG 14566.88 2
# 5 Pillars 14362.01 27
# Shell 14181.68 4
# The Week 13747.36 2
# Gazeta Wyborcza 12606.035 25
# adidas 12432.56 2
# Declic 11851.15 2
# Anita For Arizona 11564.939999999999 4
# The Beat 10769.76 2
# Sozialdemokratische Partei Europas 10290 2
# Ecosia 10207.84 7
# Socialists and Democrats Group in the European Parliament 9638.61 28
# Nissan 9383.749999999998 2
# All Out 8934.88 2
# European Youth Forum 8934 2
# Neste 8815.705 3
# Million Dollar Vegan 8718.400000000001 2
# Equality Now 8469.61 20
# Ocean Helper 7966.879999999999 2
# the DFL House Caucus, 255 East Plato Blvd, Saint Paul, MN 55107. 7735.12 15
# New York Civl Liberties Union - NYCLU 7544.12 2
# MBRC 7512.610000000001 26
# eToro 7362.52 29
# Lev Haolam - Supporting Israel's Heartland 6777.18 6
# ZAFUL 6615.37 28
# Antton Rönnholm 6461 2
# Israel365 6266.219999999999 5
# Avast Software 6041.12 4
# Riparte il futuro 6032 18
# Party of European Socialists 5990.469999999999 23
# Oxfam 5880.16 2
# World Surf League 5849.120000000001 15
# International Animal Rescue 5784.72 2
# Cisco CSR 5715.129999999999 28
# European Free Alliance 5289 6
# Timberland 5227.120000000001 5
# LGBTstyle 5072.73 28
# Greenpeace Polska 5049.845 27
# Saine Abondance 4933 2
# The Body Shop 4704.8 2
# FedEx 4687.61 27
# Gadgets Hype 4565.65 26
# Voices for Refugees - أصوات لأجل اللاجئين 4398.65 28
# WorldLifestyle 4345.68 2
# ALDE Party – Liberals and Democrats for Europe 4300.33 26
# Nunyo Demasio 4132.72 2

# %%
PAIRS = Counter()

for a in ADVERTISERS.values():
    countries = list(a['countries'])
    
    if len(countries) < 2:
        continue

    for i in range(len(countries)):
        A = countries[i]
        for j in range(i + 1, len(countries)):
            B = countries[j]
            
            if A > B:
                A, B = B, A
            
            PAIRS[(A, B)] += 1
            
for pair, count in PAIRS.most_common(15):
    print(pair, count)
# Out:
# ('AT', 'NL') 5682
# ('AT', 'GR') 5635
# ('AT', 'IE') 5595
# ('AT', 'CZ') 5472
# ('AT', 'LU') 5193
# ('BE', 'BG') 2659
# ('BE', 'ES') 2553
# ('BE', 'IT') 2478
# ('BE', 'HU') 2457
# ('AT', 'BE') 2439
# ('BE', 'SE') 2433
# ('BE', 'PL') 2430
# ('BE', 'RO') 2415
# ('BE', 'PT') 2414
# ('BE', 'MT') 2371

# %%
parliament = ADVERTISERS['European Parliament']
parliament['spent_euro'].most_common(10)
# Out:
# [('DE', 706045),
#  ('FR', 579401),
#  ('IT', 370328),
#  ('ES', 281531),
#  ('BE', 162253),
#  ('NL', 153432),
#  ('GB', 110867.68000000002),
#  ('FI', 110262),
#  ('AT', 98155),
#  ('GR', 83411)]
