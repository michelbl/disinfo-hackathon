# %%
import os
import csv
from io import StringIO
from zipfile import ZipFile
from os.path import join
from collections import defaultdict
from glob import glob

# %%
REPORTS = '../data/facebook/reports'

COUNTRIES = [
    'AT',
    'BE',
    'BG',
    'CY',
    'CZ',
    'DE',
    'DK',
    'EE',
    'ES',
    'FI',
    'FR',
    'GB',
    'GR',
    'HR',
    'HU',
    'IE',
    'IT',
    'LT',
    'LU',
    'LV',
    'MT',
    'NL',
    'PL',
    'PT',
    'RO',
    'SE',
    'SI',
    'SK',
    'US'
]

# %%
# Finding unique advertisers and the country they operate in
ADVERTISERS = defaultdict(set)

for country in COUNTRIES:
    folder = join(REPORTS, country)
    
    last_date = sorted(d for d, _, _, in os.walk(folder))[-1].split('/')[-1]
    zip_path = glob(join(REPORTS, country, last_date, '*_lifelong.zip'))[0]

    with ZipFile(zip_path) as zip:
        csv_entry = next(e for e in zip.infolist() if e.filename.endswith('.csv'))
        
        with zip.open(csv_entry.filename) as csv_f:
            csv_io = StringIO(csv_f.read().decode('utf-8-sig'))
            reader = csv.DictReader(csv_io)
            
            for line in reader:
                ADVERTISERS[line['Page Name']].add(country)

# %%
for advertiser, country in ADVERTISERS.items():
    if len(country) > 1:
        print(advertiser, country)
# Out:
# SPÖ {'AT', 'DE'}
# European Parliament {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Andreas Schieder {'AT', 'DE', 'GB'}
# HC Strache {'AT', 'DE'}
# Pamela Rendi-Wagner {'AT', 'DE'}
# European Greens {'SI', 'DK', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Karoline Edtstadler {'SI', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Johann Gudenus {'AT', 'DE'}
# Sozialdemokratische Partei Europas {'AT', 'DE'}
# Grüner Fisher Investments {'AT', 'DE'}
# EU Environment {'AT', 'GR', 'IE', 'LU', 'RO', 'BG', 'SI', 'NL', 'IT', 'FR', 'CY', 'FI', 'PL', 'DE', 'SK', 'MT', 'HR', 'LT', 'BE'}
# Tierschutzvolksbegehren {'AT', 'DE'}
# Sportnahrung {'AT', 'DE'}
# Socialists and Democrats Group in the European Parliament {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Barbara Jascht {'AT', 'DE'}
# SodaStream Deutschland {'AT', 'DE'}
# Campact e.V. {'AT', 'DE'}
# European Commission {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Die Tagesstimme {'AT', 'DE'}
# ARMEDANGELS {'AT', 'DE'}
# Luchterhand Literaturverlag {'AT', 'DE'}
# garagErasmus Foundation {'AT', 'CY'}
# Flamingos' Life {'AT', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'DE', 'BE'}
# EPP - European People's Party {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# AnyDesk {'AT', 'DE'}
# MBRC {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# FPÖ - Freiheitliche Studenten Tirol {'AT', 'IT'}
# AlpenBank {'AT', 'DE'}
# der Freitag {'AT', 'GR', 'PT', 'NL', 'ES', 'IT', 'DE', 'HR', 'BE'}
# Weltkirche Kufstein {'AT', 'DE'}
# Robert Otmar {'AT', 'DE'}
# ALDE Party – Liberals and Democrats for Europe {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Dr. Ayça KAYA {'AT', 'NL', 'FR', 'DE', 'BE'}
# wachsverpackt {'AT', 'DE'}
# TWOTHIRDS {'AT', 'LU', 'IE', 'DK', 'HU', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Lowrider Custom Kennels {'AT', 'LU', 'DE'}
# Stefan Berger {'AT', 'DE'}
# aio {'AT', 'DE'}
# Info-DIREKT {'AT', 'IT'}
# Kommando - International Special Operations Magazine {'AT', 'DE'}
# DAS BÜNDNIS für Menschenrechte & Zivilcourage {'AT', 'DE'}
# mymuesli {'AT', 'LU', 'DE'}
# Technikum Wien Academy {'AT', 'DE', 'SK'}
# A Solution to Plastic Pollution - First International Online Summit {'AT', 'IE', 'DK', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# OMV {'AT', 'DE'}
# Stoffgewickelt {'AT', 'DE'}
# LUQEL {'AT', 'DE'}
# Pöppelmann GmbH & Co. KG {'AT', 'DE'}
# MayuuLust {'AT', 'DE'}
# European Youth Event {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Jürgen Todenhöfer {'AT', 'DE'}
# Ansaar International e.V. {'AT', 'DE'}
# VIER PFOTEN {'AT', 'DE'}
# I Am Science {'AT', 'LU', 'IE', 'DK', 'SI', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SK', 'HR', 'SE', 'BE'}
# VoteWatch Europe {'AT', 'LU', 'IE', 'SI', 'EE', 'LV', 'PT', 'NL', 'ES', 'FR', 'CY', 'FI', 'DE', 'SK', 'MT', 'HR', 'LT', 'BE'}
# Wir sind nicht aus eurer Welt {'AT', 'DE'}
# Cecilia Malmström {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Yoga Store Bali {'AT', 'DE'}
# Literaturhaus Salzburg {'AT', 'DE'}
# refurbed {'AT', 'DE'}
# Beachline Festival {'AT', 'DE'}
# Katapult - Magazin {'AT', 'DE'}
# Hands on Veggies {'AT', 'DE'}
# Siedler Verlag {'AT', 'DE'}
# HUMAN BLOOD {'AT', 'DE'}
# D.Franklin {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Waste-Less.at {'AT', 'DE'}
# European Committee of the Regions {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# coliquio.de {'AT', 'LU', 'DE'}
# Gemeinsam mehr erreichen {'AT', 'DE'}
# USR Diaspora {'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'BE', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# 24Bottles {'AT', 'IE', 'DK', 'NL', 'ES', 'IT', 'FR', 'DE', 'SE', 'BE'}
# Brut UK {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Eco-clever {'AT', 'NL', 'DE'}
# Less Saves The Planet {'AT', 'LU', 'IE', 'DK', 'PT', 'NL', 'ES', 'FR', 'FI', 'SE', 'BE'}
# Gaia Wrap {'AT', 'DE'}
# Berlin Beer Week {'AT', 'LU', 'IE', 'DK', 'HU', 'BG', 'EE', 'PT', 'SI', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SE', 'BE'}
# transgen.de {'AT', 'DE'}
# European Jewish Association {'AT', 'GR', 'IE', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'DE', 'CZ', 'SK', 'LT', 'BE'}
# SMA Solar Technology {'AT', 'DE'}
# Kiwi.com {'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Online Marketing Rockstars {'AT', 'DE'}
# Fighting Heroes {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# WeTravel - Shop {'AT', 'DE'}
# Biobaula {'AT', 'DE'}
# Ammar Aldudak {'AT', 'DE'}
# stern {'AT', 'DE'}
# Kolb GesmbH {'AT', 'SI', 'DE', 'SK'}
# Stem op een Vrouw {'SI', 'DK', 'FR', 'CY', 'SK', 'HR', 'LT', 'BE', 'EE', 'LV', 'IT', 'MT', 'BG', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'LU', 'NL', 'CZ'}
# Renew Europe {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU'}
# Ullstein Verlag {'AT', 'DE'}
# AUTOMATICA {'AT', 'SI', 'DK', 'HU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SK', 'SE', 'BE'}
# Gemeinsam gegen Plastikmüll {'AT', 'DE'}
# European Youth {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Burschenschaft Markomannia Wien {'AT', 'DE'}
# RedSea Holidays {'AT', 'DE'}
# transport logistic {'FR', 'AT', 'DE', 'IT'}
# Gütersloher Verlagshaus {'AT', 'DE'}
# boopan.de {'AT', 'DE'}
# Burschenschaft Hysteria {'AT', 'DE'}
# Правда {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# SV4IE {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# SuperBee Wax Wraps {'AT', 'LU', 'SI', 'DK', 'US', 'LV', 'FI', 'SK', 'MT', 'SE', 'BE'}
# Progresívne Slovensko {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'PL', 'AT', 'LU', 'IE', 'NL', 'CZ'}
# Cosytshe {'AT', 'GR', 'IE', 'DK', 'LU', 'RO', 'PT', 'SI', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'MT', 'HR', 'SE', 'BE'}
# European Pride Organisers Association {'SI', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# Save The Seas {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Scuba Diver Life {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Kenneth Flathaug Photography {'AT', 'GR', 'DK', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Pologize Fashion {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Diem25.official {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Smarter Nutrition {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Reuswable {'AT', 'GR', 'IE', 'HU', 'RO', 'BG', 'EE', 'LV', 'PT', 'SI', 'ES', 'IT', 'CY', 'PL', 'CZ', 'MT', 'HR', 'LT'}
# Ladifit {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Terry Beech, MP {'FR', 'AT', 'IE', 'BG'}
# Umweltlich {'AT', 'DE'}
# APMS Engineering {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# On Your Sleeve {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Alexa Goddard {'SI', 'FR', 'CY', 'DE', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'LU', 'NL', 'CZ'}
# Kialo {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Innovation Origins De {'AT', 'DE'}
# Hippie Freaks - Amzitee {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Dr. Dr. Rainer Zitelmann {'AT', 'DE'}
# Straal {'FR', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# המרכז הרפורמי לדת ומדינה {'AT', 'RO', 'US', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'SE', 'BE'}
# ScienceDirect {'SI', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'LU', 'NL', 'CZ'}
# Roma EuroGames 2019 {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Zox {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Open Society Roma Initiatives {'AT', 'IE', 'DK', 'HU', 'BG', 'PT', 'RO', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SE', 'BE'}
# UNICEF Europe & Central Asia {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Shelby Leigh {'AT', 'GR', 'RO', 'BG', 'NL', 'ES', 'FR', 'DE'}
# Tshirt Month7 {'AT', 'GR', 'IE', 'DK', 'PT', 'NL', 'ES', 'IT', 'FR', 'DE', 'BE'}
# RSM MBA {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Fine Acts {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'NL', 'CZ'}
# Earthsider {'SI', 'DK', 'US', 'FR', 'DE', 'LT', 'BE', 'RO', 'EE', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL'}
# Straw Of Steel {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Hans Maes {'AT', 'BG', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'SK', 'SE', 'BE'}
# Feminist Apparel {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Gazeta Wyborcza {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ModVans {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# Waitt Foundation {'AT', 'IE', 'DK', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'DE', 'MT', 'SE'}
# Basmah {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# World Cleanup Day {'SI', 'US', 'FR', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'AT', 'GR', 'LU', 'NL', 'CZ'}
# Dokomen {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ifaw {'AT', 'DE', 'US', 'GB'}
# Laruze {'AT', 'GR', 'IE', 'NL', 'ES', 'FR', 'FI', 'DE', 'SE', 'BE'}
# Shurat HaDin - Israel Law Center {'US', 'FR', 'CY', 'DE', 'HR', 'LT', 'BE', 'RO', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'LU', 'NL', 'CZ'}
# Андрей Ситнянский {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Minnesota House DFL Campaign {'AT', 'GR', 'IE', 'LU', 'EE', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'CY', 'DE', 'MT', 'BE'}
# ITUC {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Welcomeyarn {'FR', 'AT', 'IE', 'DE'}
# Belqees.Rights {'AT', 'GR', 'HU', 'PT', 'IT', 'CY', 'FI', 'DE'}
# Get The Trolls Out {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Baby blue {'AT', 'IE', 'DK', 'NL', 'ES', 'FI', 'DE', 'SE'}
# Centre of Excellence {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Little Factory {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Better Straw {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Rroma Contact Point {'AT', 'GR', 'HU', 'RO', 'BG', 'PT', 'ES', 'IT', 'FR', 'PL', 'CZ', 'HR', 'LT'}
# Глобальный еврейский онлайн центр Jewish.Ru {'AT', 'EE', 'LV', 'US', 'DE', 'LT'}
# Spread Hope {'AT', 'GR', 'IE', 'DK', 'HU', 'NL', 'ES', 'IT', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Wholesome Culture {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Speak & Listen Translator APP {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Vivid-Rich Store {'AT', 'GR', 'IE', 'HU', 'PT', 'LV', 'NL', 'ES', 'IT', 'GB', 'PL', 'MT', 'HR', 'LT', 'BE'}
# MasterClass {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# DYLN Inspired {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'ES', 'FI', 'PL', 'SE', 'AT', 'LU', 'IE', 'NL', 'CZ'}
# HISTORY {'AT', 'DE', 'US'}
# MODA Fashion Exhibitions {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# Love Is All You Need {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The big capitalist game {'AT', 'LU', 'IE', 'DK', 'SI', 'BG', 'EE', 'LV', 'NL', 'IT', 'GB', 'FR', 'CY', 'FI', 'SE', 'DE', 'SK', 'MT', 'HR', 'LT'}
# The Epoch {'AT', 'IE', 'DK', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'HR', 'SE'}
# The Bamboo Brush Society {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Solutus Life {'AT', 'NL'}
# America Proud {'AT', 'GR', 'IE', 'DK', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Institute of Development Policy - Development Studies {'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL'}
# The New Futurist {'AT', 'GR', 'IE', 'RO', 'LV', 'IT', 'CY', 'FI', 'DE', 'CZ', 'SK', 'SE'}
# Ne u moje ime {'AT', 'HR', 'DE', 'BE'}
# EU Civil Protection & Humanitarian Aid - ECHO {'DK', 'FR', 'CY', 'DE', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'LU', 'NL'}
# Young Europe is Voting {'SI', 'DK', 'FR', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# Börsen Radio Network AG {'AT', 'DE'}
# Ośrodek Monitorowania Zachowań Rasistowskich i Ksenofobicznych {'AT', 'IE', 'NL', 'PL', 'DE', 'SE', 'BE'}
# Guitar Lovers {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Gazeta Românească {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Bestforyou6 {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Kitchen Toolkits {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# iAdvize {'FR', 'AT', 'DE'}
# StuffVip {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Exponea {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# TopstepFX {'AT', 'LU', 'DK', 'US', 'NL', 'FR', 'DE', 'SE', 'BE'}
# HP Large Format Media {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Routledge Politics, IR and Strategic Studies {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# Sustainability Times {'AT', 'IE', 'DK', 'HU', 'BG', 'EE', 'LV', 'RO', 'US', 'NL', 'FR', 'FI', 'PL', 'SE', 'CZ', 'LT', 'BE'}
# NEOPresse - Unabhängige Nachrichten {'AT', 'DE'}
# 5Pillars {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Newchic Men {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Deutschland.de {'SI', 'DK', 'US', 'FR', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Brazen Bohemian {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Globsec {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# LuXembourg - Let's make it happen {'DK', 'FR', 'DE', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Proud to be Jamaican {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Revolution Straws {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# 4IL {'SI', 'US', 'FR', 'CY', 'DE', 'SK', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'SE', 'AT', 'GR', 'IE', 'NL'}
# Milaap {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Журнал ЛЕХАИМ {'AT', 'EE', 'LV', 'IT', 'FR', 'DE', 'CZ', 'LT'}
# DRINK WORLD {'AT', 'GR', 'HU', 'RO', 'BG', 'PT', 'LV', 'ES', 'DE', 'CZ', 'SK', 'HR', 'BE'}
# Mr. Gugu & Miss Go {'SI', 'DK', 'FR', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Green Is The New Black {'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# HLK {'AT', 'DE', 'BE'}
# Radicalisation Awareness Network - RAN {'SI', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# For You {'AT', 'DK', 'NL', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SE'}
# PixelHELPER {'AT', 'RO', 'HU', 'ES', 'DE'}
# Bonny Eyes {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'EE', 'LV', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'SE', 'MT', 'HR', 'LT', 'BE'}
# Biker aus Leidenschaft {'AT', 'DE'}
# World Bank {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# East Meet East {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Protection of Animals {'AT', 'DK', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Proud of Our Pride {'AT', 'IE', 'DK', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'DE', 'SE', 'BE'}
# Comité international de la Croix-Rouge {'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# SquaredDirect {'AT', 'GR', 'IE', 'HU', 'EE', 'PT', 'NL', 'ES', 'IT', 'FR', 'CY', 'DE', 'SK', 'SE'}
# S&P Global {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Yokogawa Deutschland GmbH {'AT', 'LU', 'DK', 'IT', 'DE', 'BE'}
# Geeky Kits {'AT', 'GR', 'IE', 'DK', 'HU', 'PT', 'NL', 'ES', 'IT', 'FR', 'MT', 'HR', 'LT', 'BE'}
# Loup de Remise {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Dokomenofficial {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Spakle Of Hope {'AT', 'IE', 'HU', 'PT', 'NL', 'ES', 'IT', 'FI', 'PL', 'DE', 'BE'}
# The Rotten Fruit Box {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Fastshipgadget {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Intercept Brasil {'SI', 'DK', 'FR', 'CY', 'DE', 'HR', 'BE', 'RO', 'EE', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# PatriotPetition {'AT', 'DE', 'IT'}
# Islamic Relief CH {'AT', 'DE'}
# BCG Karriere (Deutschland/Österreich) {'AT', 'DE'}
# Expatica {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# AwareGO {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Banque mondiale {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# EU Citizens Alliance {'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'IT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'CZ'}
# Redstar73 Records {'AT', 'IE', 'ES', 'IT', 'FR', 'DE', 'SE', 'BE'}
# Justin Trudeau {'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# DRH Lindersvold {'AT', 'GR', 'SI', 'HU', 'EE', 'LV', 'PT', 'FR', 'PL', 'DE', 'HR', 'LT'}
# Noosworks.com {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Foodpowerr {'AT', 'GR', 'IE', 'DK', 'HU', 'BG', 'LU', 'NL', 'ES', 'IT', 'FI', 'DE', 'CZ', 'MT', 'SE', 'BE'}
# OPP {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Ivan Štefunko • Progresívne Slovensko {'AT', 'GR', 'IE', 'DK', 'HU', 'BG', 'SI', 'IT', 'FR', 'PL', 'DE', 'CZ', 'SK', 'BE'}
# Sikh Verband Deutschland e.V. {'AT', 'DE'}
# ForLynx {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# The Haystack {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'CZ'}
# Atomic Shirts {'AT', 'DE'}
# The New Humanitarian {'SI', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# The Lifestyle Team {'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# pro aurum Kilchberg ZH {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Forever Planet {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Quantum-Systems GmbH {'AT', 'DE'}
# Alberto Alemanno {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'IE', 'CZ'}
# Abdur-Raheem McCarthy (عبدالرحيم مكارثي) {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Newired {'AT', 'DK', 'NL', 'FR', 'FI', 'DE', 'SE', 'BE'}
# Mixing.DJ electronic music magazine {'LV', 'AT', 'PT', 'EE'}
# Hawaiiyak {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'ES', 'FI', 'PL', 'SE', 'AT', 'LU', 'IE', 'NL', 'CZ'}
# Gabz M {'FR', 'AT', 'ES', 'IT'}
# UBS Global Visionaries {'AT', 'US', 'NL', 'ES', 'IT', 'FR', 'DE', 'SE'}
# Dunja {'AT', 'DE'}
# Official: Uppsala Reggae Festival {'AT', 'DK', 'EE', 'LV', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'LT', 'BE'}
# 1 Simple Innovation {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Peruzzo S.r.l. {'AT', 'DE'}
# MarketsCube {'AT', 'IE', 'NL', 'FI', 'DE', 'HR', 'BE'}
# Uniunea Salvați România - USR {'AT', 'RO'}
# Rise for Climate Belgium: Citizen Mobilization to save Humanity {'DK', 'FR', 'DE', 'LT', 'BE', 'RO', 'EE', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# dom-i-NEEK {'AT', 'GR', 'IE', 'IT', 'FI', 'DE', 'SE', 'BE'}
# IKEA {'AT', 'DK', 'BE'}
# Screems {'AT', 'DE', 'US'}
# Islamischer Zentralrat Schweiz (IZRS) {'AT', 'DE'}
# Free Quran Education {'AT', 'IE', 'DK', 'NL', 'IT', 'FR', 'FI', 'DE', 'SE', 'BE'}
# Greens/EFA in the European Parliament {'SI', 'DK', 'DE', 'SK', 'LT', 'BE', 'RO', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Pablo Lapi  - Human Rights {'AT', 'GR', 'SI', 'HU', 'RO', 'PT', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'SK', 'BE'}
# On Trend Stuff {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Marvel Lover {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# True Rebel Store {'FR', 'AT', 'DE', 'IT'}
# Coconut Bowls {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Humble Household {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Eettisen kaupan puolesta {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ParaqinOfficial {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Lifeplus Foundation {'AT', 'ES', 'DE', 'NL'}
# kleindinst.paperart {'FR', 'AT'}
# Refugees Relief Initiative {'AT', 'GR', 'SI', 'HU', 'RO', 'BG', 'PT', 'LV', 'ES', 'IT', 'FR', 'PL', 'SE', 'DE', 'SK', 'MT', 'HR', 'LT'}
# Scelta-service {'SI', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'CZ'}
# Dunya News Kharian {'AT', 'GR', 'IE', 'DK', 'HU', 'BG', 'PT', 'RO', 'SI', 'NL', 'ES', 'IT', 'FR', 'DE', 'SK', 'MT', 'HR', 'LT', 'BE'}
# Green Economy Congress {'AT', 'HR', 'SI'}
# NewsMavens {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Mackwoods Tea {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Airis Meier Page {'AT', 'EE', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'HR', 'LT', 'BE'}
# Qatar Free Zones Authority {'AT', 'DE'}
# PNL Diaspora {'AT', 'RO', 'PT', 'ES', 'IT', 'GB', 'FR', 'DE', 'BE'}
# EU Justice and Consumers {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# EVERFX {'AT', 'GR', 'IE', 'DK', 'LV', 'NL', 'ES', 'IT', 'FI', 'SE', 'DE', 'SK', 'MT', 'LT'}
# Repatriot {'AT', 'IE', 'RO', 'ES', 'IT', 'GB', 'FR', 'PL', 'DE'}
# MadamLili Design {'AT', 'LU', 'DE'}
# Sunywayz {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Take-Pride {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# mimOOkids - Green Fashion for Small and Independent kids {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Mission {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'EE', 'LV', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'SE', 'MT', 'HR', 'LT', 'BE'}
# AllatRa TV English {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# විමසුම් අංකය {'AT', 'GR', 'IE', 'DK', 'HU', 'BG', 'LU', 'PT', 'RO', 'NL', 'ES', 'IT', 'FR', 'SE', 'DE', 'SK', 'CZ', 'MT', 'HR', 'LT'}
# Bamboo Treats {'AT', 'LU', 'DK', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'DE', 'SE', 'BE'}
# GROFA {'AT', 'DE'}
# World of Kings {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Eurac - European Academy for Executive Education {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Fairschenkt - Online Shop für nachhaltige Geschenke {'AT', 'DE'}
# Brut nature {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Sadiq Samani {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# WHOLE - United Queer Festival {'SI', 'DK', 'FR', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Vicenza Pride {'AT', 'PT', 'NL', 'ES', 'IT', 'FR', 'DE', 'SE', 'BE'}
# Eurostat {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# RoboMarkets - Global {'SI', 'DK', 'SK', 'HR', 'LT', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# dieUmweltDruckerei {'AT', 'DE'}
# Ustinoff ART {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'AT', 'GR', 'IE', 'LU', 'CZ'}
# Noufemme {'AT', 'LU', 'IE', 'DK', 'RO', 'NL', 'ES', 'IT', 'FR', 'FI', 'DE', 'HR', 'SE', 'BE'}
# A1Sports {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# One love - One Army {'AT', 'LU', 'IE', 'ES', 'IT', 'DE', 'CZ', 'MT', 'SE', 'BE'}
# Samstag Shop {'AT', 'IT'}
# Treevotion {'AT', 'LU', 'DK', 'HU', 'NL', 'IT', 'FR', 'DE', 'CZ', 'HR', 'BE'}
# Iversale {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Wise Earth Way {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'CZ'}
# Frische und Natur {'AT', 'DE', 'IT'}
# Break The Machine Ltd {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Holy Blessing {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Drapers {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Palestine Institute for Public Diplomacy {'AT', 'GR', 'IE', 'DK', 'SI', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SE', 'BE'}
# Sense Mesura {'AT', 'DK', 'NL', 'IT', 'FR', 'DE', 'BE'}
# Another Level Store {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Make-up artist & Hairstyle/Airbrushmakeup {'AT', 'SK'}
# Lula LIVRE & Dilma JA {'AT', 'ES', 'DE'}
# LGBTstyle {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Tuunes {'SI', 'DK', 'FR', 'CY', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Feel Festival {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Oceans Apart It {'AT', 'DE'}
# Cisco CSR {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Diari ARA {'AT', 'LU', 'IE', 'DK', 'EE', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'SE', 'BE'}
# План за рестартиране на демокрацията {'SI', 'DK', 'FR', 'CY', 'DE', 'BE', 'RO', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Yaqeen Institute for Islamic Research {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ONE {'SI', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# CHAMOON {'AT', 'DE'}
# Really Cool Things {'AT', 'DK', 'US', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'SE', 'BE'}
# Luxy - Upscale Dating {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Jah Happy Life {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# CropLife International {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Hoagard {'AT', 'GR', 'IE', 'DK', 'LU', 'SI', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'HR', 'LT', 'BE'}
# Her Dream House {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Films du Losange {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Dr. Mohamed Elhachmi Hamdi د. محمد الهاشمي الحامدي {'AT', 'NL', 'IT', 'FR', 'PL', 'DE', 'SE', 'BE'}
# Orbex {'SI', 'DK', 'US', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'GB', 'HU', 'BG', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL'}
# Swell Lodge {'SI', 'FR', 'CY', 'DE', 'HR', 'LT', 'BE', 'RO', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL'}
# Bommelig.de by Alexander {'AT', 'LU', 'NL', 'IT', 'FR', 'DE', 'SE', 'BE'}
# Fischfarm Schubert {'AT', 'DE'}
# Dein Magnetmotor {'AT', 'DE'}
# Global Citizen {'SI', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# FFF {'AT', 'LU', 'DE'}
# News Now {'AT', 'LU', 'IE', 'DK', 'NL', 'FR', 'FI', 'DE', 'SE', 'BE'}
# Ceramica.info {'AT', 'NL', 'FR', 'DE', 'BE'}
# Global School for Social Leaders {'AT', 'SI', 'HU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'CZ', 'LT', 'BE'}
# Xytro {'AT', 'GR', 'IE', 'DK', 'HU', 'BG', 'LU', 'NL', 'ES', 'IT', 'FR', 'FI', 'DE', 'CZ', 'MT', 'SE', 'BE'}
# Flaka Sailing - The Blue Cruise Specialist {'AT', 'NL', 'ES', 'IT', 'DE', 'SE', 'BE'}
# Talking Europe {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Even Miracles Take A Little Time {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Ambassador of Islam {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Human Rights Tattoo {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Eldritch Foundry {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Intersolar {'AT', 'GR', 'LU', 'HU', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'BE'}
# Vaginore {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Bambooster {'AT', 'GR', 'IE', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# PROGRESĪVIE {'AT', 'LU', 'IE', 'BG', 'EE', 'LV', 'PT', 'NL', 'ES', 'GB', 'FI', 'SE', 'CZ', 'MT', 'LT', 'BE'}
# Brut nature FR {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# FAEF Federal Alliance of European Federalists {'AT', 'GR', 'HU', 'RO', 'BG', 'EE', 'LV', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'CZ', 'MT', 'HR', 'LT', 'BE'}
# JackyStore {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'FI', 'SE', 'DE', 'LT', 'BE'}
# Pampers Russia {'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# BrightThis {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Antisemitismus Bekämpfen {'AT', 'DE'}
# Conflict Of Nations : World War 3 {'SI', 'DK', 'US', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Flora & Fauna {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Charmed Aroma {'AT', 'IE', 'US', 'NL', 'ES', 'IT', 'SE', 'BE'}
# UNFCCC {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# United World İnternational {'AT', 'GR', 'HU', 'ES', 'IT', 'FR', 'PL', 'DE', 'SE'}
# From The Reserve {'AT', 'GR', 'IE', 'HU', 'RO', 'ES', 'IT', 'FR', 'CY', 'FI', 'DE', 'MT', 'BE'}
# BeautyPreneur {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# آزادی {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# POLITICO Europe {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Klimawende {'AT', 'DE'}
# Stephanie & Hans von: Authentisch und erfolgreich {'AT', 'DE'}
# WomanSpeak {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'LT', 'BE', 'RO', 'EE', 'IT', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# KTREW Tattoo {'AT', 'IE', 'PT', 'ES', 'IT', 'FR', 'FI', 'DE', 'SE', 'BE'}
# China Daily {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Zora Jaurová • Progresívne Slovensko {'AT', 'LU', 'IE', 'HU', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'CZ', 'SK', 'HR', 'BE'}
# Hot Special Discount {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Uncommon {'AT', 'GR', 'IE', 'HU', 'LU', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE', 'SE', 'BE'}
# Autor Michael F. Stelzer {'AT', 'DE'}
# SwatiManish {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Tilburg University {'SI', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'NL', 'CZ'}
# OWTE Oil Limited {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Newchic_Men {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# TVP Polonia {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Veganuary {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Professionnelle#Marocain {'AT', 'GR', 'HU', 'PT', 'ES', 'IT', 'FR', 'DE', 'CZ', 'SK', 'BE'}
# Michal Truban {'AT', 'GR', 'IE', 'HU', 'LU', 'BG', 'PT', 'LV', 'SI', 'NL', 'ES', 'IT', 'FR', 'CY', 'PL', 'DE', 'CZ', 'SK', 'SE', 'BE'}
# Couple-tee shirts {'AT', 'RO', 'PT', 'LV', 'ES', 'IT', 'FR', 'DE', 'HR', 'SE', 'BE'}
# Hungary Today {'SI', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Meniga {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Canberra Short Film Festival {'AT', 'GR', 'NL', 'ES', 'IT', 'FR', 'PL', 'DE'}
# Accor Group {'AT', 'GR', 'IE', 'HU', 'RO', 'PT', 'IT', 'PL', 'LT'}
# Mambles {'AT', 'LU', 'IE', 'DK', 'HU', 'US', 'NL', 'ES', 'IT', 'FR', 'FI', 'PL', 'DE', 'SE', 'BE'}
# Icebreaker {'AT', 'LU', 'SI', 'DK', 'EE', 'LV', 'US', 'NL', 'ES', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SK', 'SE', 'BE'}
# MOTU swim {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Real Time China {'AT', 'LU', 'DE', 'BE'}
# Academic Stories {'SI', 'FR', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'PL', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Remix News & Views {'AT', 'DK', 'HU', 'RO', 'NL', 'IT', 'FR', 'PL', 'DE', 'CZ', 'SK', 'SE', 'BE'}
# Soviet Visuals {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Snkraddicted {'AT', 'DE'}
# I stand for my Country {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# GEO {'AT', 'DE'}
# Scoutshirts {'AT', 'DK', 'NL', 'FI', 'PL', 'DE', 'CZ', 'SE', 'BE'}
# Basarabia e România {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ABB {'FR', 'AT', 'SE', 'DE'}
# Transylvania NOW {'AT', 'NL', 'ES', 'IT', 'GB', 'FR', 'FI', 'PL', 'DE', 'CZ', 'SK', 'BE'}
# Parag Khanna {'AT', 'GR', 'IE', 'LU', 'SI', 'EE', 'PT', 'US', 'NL', 'ES', 'IT', 'FR', 'CY', 'FI', 'DE', 'CZ', 'BE'}
# Ocean Witness {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Malaysiakini {'SI', 'DK', 'FR', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Adorbs {'AT', 'GR', 'IE', 'DK', 'HU', 'LU', 'EE', 'LV', 'PT', 'NL', 'ES', 'IT', 'FR', 'PL', 'MT', 'HR', 'LT', 'BE'}
# ElectronicSpecifier {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Highride {'AT', 'DK', 'NL', 'IT', 'DE', 'SE', 'BE'}
# Global Times {'SI', 'DK', 'US', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# The Good Lobby {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'GB', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# Now_Then {'AT', 'LU', 'IE', 'DK', 'PT', 'NL', 'FR', 'DE', 'SE', 'BE'}
# BetterMe {'SI', 'DK', 'FR', 'CY', 'DE', 'SK', 'HR', 'LT', 'BE', 'RO', 'EE', 'LV', 'IT', 'MT', 'HU', 'BG', 'PT', 'ES', 'FI', 'PL', 'SE', 'AT', 'GR', 'IE', 'LU', 'NL', 'CZ'}
# ...
# Team Global Future {'SE', 'DK'}
# Lega Recanati {'DK', 'IT'}
# Demokrati utan gränser {'SE', 'DK'}
# Natural Thriving - Green Living Boutique {'DK', 'US'}
# Taiyoen {'FI', 'SE', 'DK'}
# Investerarbrevet {'SE', 'DK'}
# Nel Hydrogen {'SE', 'DK'}
# أخبار الهجرة واللجوء الى كندا {'GR', 'DK', 'NL', 'FI', 'SE'}
# AmazingApps {'GR', 'IE', 'DK', 'SE'}
# Genusvetenskapliga institutionen, Lunds universitet {'SE', 'DK'}
# The Sorgentian {'SI', 'DK', 'PT', 'NL', 'ES', 'IT', 'FI', 'MT'}
# Peakon {'FI', 'SE', 'DK'}
# SustainablyFine {'DK', 'US'}
# Fred Keller {'DK', 'US', 'PT', 'ES', 'FR'}
# Reformierakond {'US', 'EE'}
# Михаил Ходорковский {'PL', 'IT', 'EE'}
# IPG - Международная политика и общество {'LV', 'LT', 'EE'}
# Хохотушка {'EE', 'LV', 'ES', 'IT', 'LT'}
# BBC News Russian {'LV', 'LT', 'US', 'EE'}
# Ритм Евразии {'LV', 'EE'}
# RuBaltic.Ru {'LV', 'LT', 'EE'}
# Yarvensivu Dmitry- Financial success {'LV', 'ES', 'EE'}
# adidas {'ES', 'US'}
# Ben & Jerry's {'NL', 'ES', 'US', 'GB'}
# National Geographic {'SI', 'NL', 'ES'}
# Acciona {'ES', 'US'}
# European GNSS Agency {'FR', 'ES'}
# Chela {'ES', 'PT'}
# Carpisa {'GR', 'ES', 'HR'}
# Hi Fly {'FR', 'ES', 'PT'}
# Civil Liberties Union for Europe {'ES', 'GB'}
# Vaqueros Colombianos {'FR', 'ES'}
# YAC {'FR', 'ES', 'IT', 'US'}
# Galaxy Kayaks España {'ES', 'PT'}
# Euronews English {'GR', 'PT', 'ES', 'IT', 'FR'}
# Selectra {'FR', 'ES'}
# Choose the planet {'ES', 'US'}
# CAPEX España - precedentemente CFDGlobal España {'ES', 'PT'}
# Irungo Harrera Sarea / Red de Apoyo de Irun {'FR', 'ES'}
# La Dame d'Aragon {'FR', 'ES'}
# The Objective {'ES', 'US'}
# diegolongobardi {'FR', 'ES', 'IT'}
# Gravinergy for the Earth {'FR', 'ES', 'IT'}
# Caro Marketing (NY/LA) {'FR', 'ES'}
# Decisión Nacional Amé Presidente {'ES', 'US'}
# No Coal Japan {'FR', 'IE', 'ES', 'NL'}
# Insights FR {'FR', 'ES', 'RO', 'MT'}
# Vivero La Palmera {'FR', 'ES', 'IT', 'PT'}
# MERmänsklighet Umeå {'SE', 'ES', 'IT'}
# Evarvest {'PL', 'ES', 'LT', 'PT'}
# The Jonathan Project srl {'FR', 'ES', 'IT'}
# Bachclip {'GR', 'IE', 'ES', 'FR', 'PL'}
# Action 4 Equality Scotland Ltd {'IE', 'PT', 'NL', 'ES', 'PL', 'SK'}
# Banco Mundial {'ES', 'US'}
# Institut Francophone pour la Justice et la Démocratie - ex-IUV {'FR', 'ES'}
# NAAMAT INTERNATIONAL {'FR', 'ES', 'US'}
# Lucia Zakopčanová {'ES', 'SK', 'PT'}
# L-Ever {'ES', 'IT'}
# Sun Investment Group {'HU', 'ES', 'PL', 'SK', 'LT'}
# Anita For Arizona {'PL', 'GR', 'ES', 'US'}
# Floreria Lizette Mty {'FI', 'ES'}
# airems {'FR', 'ES', 'IT'}
# Lilium's Art {'FR', 'ES', 'IT', 'RO'}
# Kyero.com {'LU', 'ES', 'IT'}
# KANA MATSUNAMI {'FR', 'ES'}
# UNAM Universidad Nacional Autónoma de México {'ES', 'PT'}
# Adrian George Coman {'IE', 'RO', 'ES', 'IT', 'FR'}
# WaiWai {'ES', 'RO'}
# Dinero llama dinero {'ES', 'US'}
# VINNIA {'HR', 'ES', 'PT', 'HU'}
# Hija de Quisqueya {'FR', 'ES', 'IT'}
# Charge Or Walk {'ES', 'US'}
# Alkaline-Flow Lifestyle {'SE', 'ES'}
# Nils Torvalds {'FI', 'ES'}
# Anastasia Osipovich {'GR', 'ES', 'IT'}
# CEMEX {'ES', 'US'}
# Fastidio {'FR', 'GR', 'ES', 'IT'}
# World Events with Logical Prudency {'FR', 'ES', 'IT'}
# Nate Hancock and The Declaration {'ES', 'US'}
# Evitas.it {'ES', 'IT', 'RO', 'HU'}
# Les Observateurs - France 24 {'FR', 'ES'}
# アレッサンドロ {'FR', 'ES', 'IT'}
# Talking Trees: Adult Survivors of CSA {'HU', 'PT', 'ES', 'IT', 'SK', 'HR'}
# FACE Magazine.it {'ES', 'IT'}
# Lalique Nelson {'GR', 'ES', 'US'}
# Nilbull {'FR', 'ES'}
# Hippy Cream {'ES', 'PT'}
# Sportello d'Ascolto {'ES', 'IT'}
# Colm Taylor - Cashel & Tipperary Candidate {'FR', 'ES', 'IT', 'PT'}
# Maha Devi Li Ra La {'GR', 'ES', 'PT'}
# Quilla {'FR', 'ES', 'IT'}
# I Feel Your Style {'PL', 'NL', 'ES', 'RO'}
# Rebañando {'ES', 'IT', 'PT'}
# Alain Lamassoure {'FR', 'ES'}
# Bachelorstudies {'SI', 'LV', 'ES', 'PL', 'HR'}
# Parental alienation is child abuse {'IE', 'ES', 'SE'}
# Tour Guide Paris {'NL', 'ES'}
# Nextdoor {'ES', 'US'}
# Gabyanna Negra e Gorda {'IE', 'PT', 'ES', 'IT', 'FR'}
# Mi.Te {'ES', 'IT'}
# Kokoomus {'FI', 'GB'}
# Neste {'FI', 'SE', 'US'}
# SSAB AB {'FI', 'SE'}
# Maija Kaunismaa {'FI', 'US'}
# Kirkon Ulkomaanapu {'FI', 'US'}
# Into {'FI', 'US'}
# University of Helsinki {'FI', 'US'}
# LawlessLatvia {'IE', 'LV', 'FI', 'MT', 'SE'}
# Stora Enso {'FI', 'SE'}
# Happiness Initiation {'FI', 'NL'}
# CHOOOSE {'FI', 'SE', 'US'}
# Semantiko {'FI', 'SE'}
# NJC - Nordisk Journalistcenter {'FI', 'SE'}
# World on Fire {'FI', 'SE'}
# Saine Abondance {'FR', 'LU'}
# The Body Shop {'FR', 'US'}
# Comme Avant {'FR', 'US'}
# Janina Rossiter {'FR', 'US'}
# Coral Guardian {'FR', 'US'}
# Coming Out {'FR', 'US'}
# TOMS {'FR', 'NL', 'US'}
# We Build Value {'FR', 'US'}
# ABB Formula E {'FR', 'US', 'GB'}
# The Fetzer Institute {'IE', 'US', 'IT', 'FR', 'SE'}
# Furahini {'FR', 'SE'}
# James Hsiang Hong/ Hsiang-chih Hung/ 洪祥智 {'FR', 'IT', 'US'}
# Ocean Sweep {'FR', 'US'}
# Liviane {'FR', 'NL'}
# 寄付ナビ {'FR', 'NL', 'SE'}
# Annahar English {'FR', 'US'}
# Innerbottle {'FR', 'US'}
# World Global Warming {'FR', 'IE'}
# BeingSikh66 {'FR', 'IT', 'US'}
# Arçelik Global {'FR', 'PL', 'RO'}
# Anna Maria Sandegren {'FR', 'SE'}
# Sawab Center FR {'FR', 'US'}
# World2day {'FR', 'IT', 'US'}
# The Hardest Word Podcast {'FR', 'SE'}
# Hido-Yeelo {'FR', 'NL', 'IT'}
# Cerm lab {'FR', 'IT'}
# Amadou GON Coulibaly {'FR', 'IT', 'US'}
# 350.org {'FR', 'US'}
# Drinkay {'FR', 'IT'}
# Green Nature {'FR', 'HU', 'PT'}
# Essity Careers {'FR', 'SE'}
# Noocity Urban Ecology {'FR', 'LU'}
# Alberto Bona {'FR', 'IT'}
# Søstrene Grene {'FR', 'IE'}
# Nevolighter {'FR', 'US'}
# Case For Change {'FR', 'US'}
# Ng Foundation Inc {'FR', 'GR'}
# COTTON USA {'FR', 'IT'}
# Malaysia Life Line for Syria {'FR', 'LU'}
# Московский Центр Карнеги {'US', 'LV', 'IT', 'FR', 'PL'}
# Husn Energy Solutions {'FR', 'PL'}
# David Stephen Patterson {'FR', 'SI', 'IT', 'MT'}
# Essity {'FR', 'NL', 'SE', 'US'}
# Aberdeen Standard Investments Global {'FR', 'US'}
# Mahindra Rise {'FR', 'IT', 'US'}
# LaVie {'FR', 'US'}
# MUBI {'FR', 'US', 'GB'}
# International Monetary Fund {'FR', 'US'}
# ANTICLIMBERS {'FR', 'PL', 'LT', 'LV'}
# TechTheLead {'FR', 'IE', 'US'}
# The Nail Lab {'FR', 'IT', 'PT'}
# Renew {'US', 'GB'}
# London Labour Party {'US', 'GB'}
# The Week UK {'US', 'GB'}
# Alex Salmond {'IE', 'GB'}
# Million Dollar Vegan {'US', 'GB'}
# International Animal Rescue {'US', 'GB'}
# The News Dump {'US', 'GB'}
# Green Lane Masjid {'US', 'GB'}
# Extinction Rebellion {'US', 'GB'}
# Global Optimism {'US', 'GB'}
# Jamie Smart {'US', 'GB'}
# Yusuf Chambers {'US', 'GB'}
# RepresentUs {'US', 'GB'}
# RSPCA (England & Wales) {'US', 'GB'}
# The Radical Tea Towel Company {'US', 'GB'}
# Andrea Venzon {'IT', 'GB'}
# Hatch {'US', 'GB'}
# Modius Health {'US', 'GB'}
# Fleur for Putney {'US', 'GB'}
# Pay Justice {'US', 'GB'}
# CAFOD {'US', 'GB'}
# InterTradeIreland {'IE', 'GB'}
# Success Resources {'US', 'GB'}
# SABA Relief & Development Foundation {'US', 'GB'}
# HowTheLightGetsIn Festival {'US', 'GB'}
# Hartiful - Pins and Patches {'US', 'GB'}
# KM Digital {'US', 'GB'}
# Dose of Society {'IE', 'US', 'GB'}
# United for Change {'US', 'GB'}
# Kevin Nicholson {'US', 'GB'}
# PlasticNegative {'US', 'GB'}
# Global Teaching Network {'US', 'GB'}
# RBG {'US', 'GB'}
# Eco Straw {'US', 'GB'}
# Ocean Helper {'US', 'GB'}
# Unseen {'US', 'GB'}
# Saving The Survivors {'US', 'GB'}
# PositiveLuxury {'US', 'GB'}
# Nativve {'US', 'GB'}
# Lilongwe Wildlife Trust {'US', 'GB'}
# Cool Earth {'US', 'GB'}
# The B1M {'US', 'GB'}
# Tom Morrison {'US', 'GB'}
# Fight for Wildlife {'US', 'GB'}
# EU Leavers Party {'US', 'GB'}
# Haymarket Books {'US', 'GB'}
# International Growth Centre {'US', 'GB'}
# Showcase {'US', 'GB'}
# CPIC {'US', 'GB'}
# The British Journal of Photography {'US', 'GB'}
# British Online Archives - Primary source collections for higher education {'US', 'GB'}
# UnHerd {'US', 'GB'}
# Audible {'US', 'GB'}
# New Life Community Church {'US', 'GB'}
# NIESR {'US', 'GB'}
# UNITED SIKHS {'US', 'GB'}
# The Ronains {'US', 'GB'}
# Geographical Magazine {'US', 'GB'}
# Meeting of Minds UK {'US', 'GB'}
# Mothers of Invention {'US', 'GB'}
# Michael Durban {'US', 'GB'}
# UKIP East Cheshire {'US', 'GB'}
# AFTP News {'IE', 'GB'}
# SKT Welfare {'US', 'GB'}
# CFD Global {'IE', 'GB'}
# The VganTribe Co. {'US', 'GB'}
# The Conch News {'US', 'GB'}
# Daily Feed {'US', 'GB'}
# We Are Endangered {'US', 'GB'}
# Graffiti Kings {'US', 'GB'}
# M.K. Drake - Atticus and the Majjai Six {'US', 'GB'}
# Arcticus {'US', 'GB'}
# A r c h i E {'US', 'GB'}
# Steven Woolfe MEP {'US', 'GB'}
# GCN {'IE', 'GB'}
# GNI {'IE', 'GB'}
# Councillor Andrew Zbik - Lane Cove Council {'US', 'GB'}
# Manhattan Neighborhood Network - MNN {'US', 'GB'}
# OZY World {'US', 'GB'}
# Smart Money {'US', 'GB'}
# Bloverse {'US', 'GB'}
# Sam Crossland {'US', 'GB'}
# MGI Construction Corp. {'US', 'GB'}
# Dean Graziosi {'US', 'GB'}
# Simona Petrík SPOLU - občianska demokracia {'SK', 'GB'}
# Wibbitz {'US', 'GB'}
# Raseef22  رصيفــ22 {'US', 'GB'}
# BEAUTY小舖。寵愛你的美麗 {'US', 'GB'}
# Federal National Council {'US', 'GB'}
# Feminists in History {'SE', 'GB'}
# History Collection {'US', 'GB'}
# Bitdefender {'US', 'GB'}
# Care2 {'US', 'GB'}
# NewChic {'US', 'GB'}
# Ведомости {'US', 'GB'}
# Consumer Choice Center {'US', 'GB'}
# Dating.com {'US', 'GB'}
# The Pretty Life {'US', 'GB'}
# Asia Times - India {'US', 'GB'}
# OORR {'US', 'GB'}
# WorldLifestyle {'US', 'GB'}
# China Xinhua News {'US', 'GB'}
# GiveMeSport {'US', 'GB'}
# Zelna Jansen Consultancy {'US', 'GB'}
# Info West Papua {'NL', 'US', 'GB'}
# Arbetet Global {'SE', 'GB'}
# Национальный расчетный депозитарий {'US', 'GB'}
# Конгрессно-Выставочная Компания «Империя» {'US', 'GB'}
# Dave Bieter for Boise {'US', 'GB'}
# The Commentator {'US', 'GB'}
# Gazeta.pl {'PL', 'GB'}
# DressSure {'US', 'GB'}
# The Boucher Legacy {'US', 'GB'}
# 2019 Better Living Daily {'US', 'GB'}
# Philosophie Wellness {'US', 'GB'}
# Ruptly {'US', 'GB'}
# Eco Lifestyle {'US', 'GB'}
# Anglican Mainstream {'IE', 'GB'}
# Hustle Ramen {'US', 'GB'}
# Fibrenew International {'US', 'GB'}
# West Papua Indonesia {'NL', 'US', 'GB'}
# Brexit: The Board Game of Second Chances {'US', 'GB'}
# Stronger Together {'US', 'GB'}
# ORU {'US', 'GB'}
# PLANADVISER {'US', 'GB'}
# State House Sierra Leone {'US', 'GB'}
# Peter Bunting, MP {'US', 'GB'}
# TheTruth {'US', 'GB'}
# Innosity {'US', 'GB'}
# 大紀元&新唐人－舊金山（EpochTimes & NTDTV - San Francisco） {'US', 'GB'}
# Stanford Graduate School of Business {'US', 'GB'}
# Free West Papua Campaign {'US', 'GB'}
# Keith Butler Ministries {'US', 'GB'}
# T'es de Dakar_Officiel {'US', 'GB'}
# Quotes {'US', 'GB'}
# Lottie Dolls {'US', 'GB'}
# Freedom - Is The World Free Today? {'US', 'GB'}
# حزب کمونیست کارگری ایران {'US', 'GB'}
# Liberal Party of Canada | Parti libéral du Canada {'US', 'GB'}
# TENCEL {'US', 'GB'}
# MBR Initiative for Global Prosperity {'US', 'GB'}
# Lucia Kleštincová {'SK', 'GB'}
# Women for Justice {'US', 'GB'}
# Brand Hong Kong {'US', 'GB'}
# Parents for Public Charter Schools {'US', 'GB'}
# Epic Charter Schools {'US', 'GB'}
# Nikkei Asian Review {'US', 'GB'}
# שמעון מזוז  Shimon Mazuz {'US', 'GB'}
# Knight Frank {'US', 'GB'}
# New/Mode {'US', 'GB'}
# Tanistry: Irish History {'US', 'GB'}
# GZERO World with Ian Bremmer {'US', 'GB'}
# Missions Ministry Non Profit Corporation {'US', 'GB'}
# Chihuahua Books {'US', 'GB'}
# All Out {'US', 'GB'}
# I Overcame Anxiety {'US', 'GB'}
# NUNYO & COMPANY {'US', 'GB'}
# GETAnalysis {'US', 'GB'}
# The Korea Herald {'US', 'GB'}
# ActivTrades {'IE', 'NL', 'GB'}
# AvaTrade {'IE', 'GB'}
# Gluten Sugar Dairy Free Lifestyle {'US', 'GB'}
# Document.no {'US', 'GB'}
# Badtameez Bahu {'US', 'GB'}
# يورو تايمز - Euro Times {'SE', 'GB'}
# IMS ExpertServices {'US', 'GB'}
# Outschool {'US', 'GB'}
# Mars Global Careers {'US', 'GB'}
# Alex Bishop {'US', 'GB'}
# Viral Shared {'US', 'GB'}
# Alice Mary Higgins for Europe {'IE', 'GB'}
# RBC Wealth Management {'US', 'GB'}
# Le Monde {'US', 'GB'}
# Brasil Wire {'US', 'GB'}
# Art of Safari {'US', 'GB'}
# Clone Evolution {'US', 'GB'}
# Light The Fire {'US', 'GB'}
# It's Time to FITE {'US', 'GB'}
# Transatlantic Forum for Education and Diplomacy {'US', 'GB'}
# The Daily Conservative {'US', 'GB'}
# Partidul Naţional Liberal {'RO', 'GB'}
# Dakota sky {'US', 'GB'}
# Gript {'IE', 'GB'}
# Scholarships for International Students {'US', 'GB'}
# The Free Markets Series {'US', 'GB'}
# Naomi Reniuț-Ursoiu {'RO', 'GB'}
# INA- Iliria News Agency {'US', 'GB'}
# Save Our Schools {'US', 'GB'}
# Vegan Lovers {'US', 'GB'}
# Ελένη Μυλωνοπούλου-Τσάτση: Υποψήφια Ευρωβουλευτής {'GR', 'RO'}
# Vot-EU Project {'PL', 'GR', 'IT'}
# Νέα Πολιτική Κίνημα Δημοκρατικής Κοινωνικής Αναθέσμισης {'GR', 'US'}
# Career Jobs Hunt Network {'GR', 'LU'}
# Appeal of Conscience Foundation {'PL', 'GR', 'SK', 'HR'}
# Travis Riddick Photography {'GR', 'IT'}
# Eurasianet {'GR', 'RO', 'PT'}
# Distinct Nova {'GR', 'LT', 'RO', 'PT'}
# Eclectica {'HR', 'US'}
# Antun Babić kandidat za predsjednika države {'HR', 'US'}
# Goethe-Zentrum Triest {'HR', 'IT', 'SI'}
# Almir Terzić {'HR', 'SI'}
# Simona Antonovic - make up artist {'HR', 'SI'}
# ZÖLD Csillag {'HR', 'HU', 'RO'}
# Mujalonga sul Mar 2019 {'HR', 'IT', 'SI'}
# Patto per l'Autonomia - Trieste {'HR', 'IT'}
# MCT- Master Change Training {'HR', 'SI'}
# Chicken Without a Head sprl {'HR', 'RO', 'SK'}
# Specijalna Bolnica Sv. Katarina {'HR', 'SI'}
# KDNP és Frakciója {'HU', 'RO', 'SK'}
# Mága Zoltán hegedűművész {'HU', 'RO'}
# Budapest Water Summit 2019 {'HU', 'US'}
# Vasarnap.hu {'HU', 'RO'}
# CSE Australia {'HU', 'RO', 'SK'}
# Victoria Moda Magyarország {'HU', 'SK'}
# G7.hu {'HU', 'RO', 'SK'}
# Székely Nemzeti Tanács {'HU', 'RO'}
# Progresívne Slovensko je Socialistická strana {'HU', 'SK'}
# Nissan {'HU', 'US'}
# Oxfam {'IE', 'US'}
# Michael Clark {'IE', 'US'}
# Focus Ireland {'IE', 'US'}
# Aircall {'IE', 'NL'}
# Dave O'Keeffe - People Before Profit {'IE', 'US'}
# Breaking News {'IE', 'US'}
# Abortion Rights Campaign {'IE', 'US'}
# Flanders Fields 14-18 {'IE', 'US'}
# Tundra {'IE', 'US'}
# BeWrap {'IE', 'SE', 'US'}
# Unreasonable {'IE', 'US'}
# Jody & Christie {'LU', 'IE'}
# Know Islam {'IE', 'US'}
# PoliQuads Magazine {'IE', 'US'}
# China Spotlight {'IE', 'US'}
# Condemi Assessoria {'IE', 'IT', 'PT'}
# Discover Philadelphia {'IE', 'IT'}
# Kaylee Walker {'IE', 'US'}
# Trinity Long Room Hub Arts and Humanities Research Institute {'IE', 'US'}
# Patagonia {'IE', 'US'}
# Laurent Law - New Zealand Immigration Specialists {'IE', 'PT'}
# Paleo f(x) {'IE', 'US'}
# GuidetoIslam.com {'PL', 'IE', 'SI'}
# Microsoft Education {'IE', 'US'}
# Green Little Things {'IE', 'US', 'PT'}
# Pfane Environmental Association {'IE', 'US'}
# Deborah Morgan Author {'IE', 'US'}
# The BL TV {'SI', 'IE', 'SE', 'US'}
# Etihad Airways {'IE', 'US'}
# Yellowed {'IE', 'NL'}
# Polscy Patrioci w Irlandii {'PL', 'IE'}
# Virtue Online {'IE', 'US'}
# Coca-Cola {'IT', 'US'}
# Orlando Amodeo per Europa Verde {'IT', 'US'}
# ISPI - Istituto per gli studi di politica internazionale {'IT', 'US'}
# Enel Group {'RO', 'IT', 'US'}
# Anna Ascani {'IT', 'US'}
# Gun Rights {'IT', 'US'}
# Greenpeace International {'NL', 'IT'}
# Freedom {'IT', 'US'}
# Associazione Luca Coscioni {'IT', 'US'}
# Insieme Per Magliano {'IT', 'US'}
# Plastic Free {'IT', 'US'}
# Mons Gibel Camping Park - Area Attrezzata Camper {'IT', 'MT'}
# GeoMovies {'IT', 'MT'}
# Gazeta Ukrainska, il giornale per gli ucraini in Italia {'IT', 'MT'}
# Jersey Landscape Sonnets Waceofjersey {'US', 'IT', 'PT'}
# Francesca Alderisi {'IT', 'US'}
# Rosa Brunello {'SI', 'IT'}
# Car Products {'RO', 'IT', 'SK'}
# ALL in Trade Limited {'US', 'IT', 'PT'}
# ThemBay {'RO', 'IT'}
# Trivelsicilia di Castelli Domenico srl {'IT', 'MT'}
# Gariwo - Foresta dei Giusti {'IT', 'US'}
# Reikientuvida-central {'IT', 'PT'}
# Už Ingridą {'LT', 'US'}
# Mindaugas Puidokas {'LT', 'US'}
# Evropski pokret u Srbiji {'PL', 'LT', 'RO'}
# Быстро. Легко. Вкусно {'LV', 'LT'}
# Новости Украины - Replyua {'PL', 'LT'}
# Cali Lili {'LV', 'SE', 'US'}
# Bas Eickhout {'NL', 'US'}
# Stem Roy Europa in {'NL', 'US'}
# Chivas Regal {'NL', 'US'}
# Skillpower {'NL', 'SE', 'US'}
# Hivos {'NL', 'US'}
# Luna Loca {'NL', 'US'}
# Games area {'NL', 'SE'}
# rPlanet Earth {'NL', 'US'}
# Andrew Powell {'NL', 'SE'}
# Akcja Demokracja {'PL', 'US'}
# Seventh Generation {'PL', 'US'}
# OKO.press {'PL', 'US'}
# Civilekonomerna {'PL', 'SE'}
# Globalist Party {'US', 'PT'}
# Michelle Cechin - Brincaginação {'US', 'PT'}
# Bianca Santos {'US', 'PT'}
# Freebiz Network {'US', 'PT'}
# Declic {'RO', 'US'}
# SOS Satele Copiilor Romania {'RO', 'US'}
# Tanase Stamule {'RO', 'US'}
# Demos {'RO', 'US'}
# New York Civil Liberties Union {'RO', 'US'}
# Centerpartiet {'SE', 'US'}
# Kristdemokraterna {'SE', 'US'}
# Världsnaturfonden WWF {'SE', 'US'}
# Wedonthavetime.org {'SE', 'US'}
# ReSound {'SE', 'US'}
# Evensi {'SE', 'US'}
# L'Union Féministe Libre - UFL - الاتحاد النسائي الحر {'SE', 'US'}
# ClimateLaunchpad {'SI', 'US'}
# Maroš Šefčovič {'US', 'SK'}
# Netky.sk {'US', 'SK'}
